# %%
import os
import sys
import importlib

sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(''))))
from utilities.path_utils import *
import pandas as pd

# %%
data1 = pd.read_csv(get_raw_data_path('netrisk_casco_2024_02_09', '.csv'))
data2 = pd.read_csv(get_raw_data_path('netrisk_casco_2024_01_33', '.csv'))
data3 = pd.read_csv(get_raw_data_path('netrisk_casco_2024_01_34', '.csv'))

# %%
data1
# Out:
#       id_case DateCrawled  isRecent CarMake CarModel  CarAge   ccm  kw    kg  \
# 0        1135  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
# 1        1136  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
# 2        1137  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
# 3        1138  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
# 4        1139  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
# ...       ...         ...       ...     ...      ...     ...   ...  ..   ...
# 2666     3801  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
# 2667     3802  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
# 2668     3803  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
# 2669     3804  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
# 2670     3805  2024_02_09     False  TOYOTA  Corolla       1  1197  85  1390
#
#       car_value  ...  GENERALI_price  GENERTEL_price  GROUPAMA_price  \
# 0       25532.0  ...        299714.0             NaN             NaN
# 1       25532.0  ...        258700.0             NaN        172596.0
# 2       25532.0  ...        299714.0             NaN        186192.0
# 3       25532.0  ...        283939.0             NaN        172596.0
# 4       25532.0  ...        299714.0             NaN        172596.0
# ...         ...  ...             ...             ...             ...
# 2666    25532.0  ...        283939.0             NaN        179292.0
# 2667    25532.0  ...        299714.0             NaN        179292.0
# 2668    25532.0  ...        299714.0             NaN             NaN
# 2669    25532.0  ...        283939.0             NaN        172596.0
# 2670    25532.0  ...        347037.0             NaN        192876.0
#
#       K&AMP;H_price  KÖBE_price  MAGYAR_price  SIGNAL_price  UNION_price  \
# 0          371602.0     90036.0      100000.0      156193.0     190987.0
# 1          306177.0     90036.0      100000.0      156193.0     190987.0
# 2          283552.0     82716.0      100000.0      156193.0     190987.0
# 3          322156.0     88206.0      100000.0      156193.0     202221.0
# 4          274321.0     90036.0      100000.0      156193.0     202221.0
# ...             ...         ...           ...           ...          ...
# 2666       239577.0     69906.0      100000.0      218670.0     190987.0
# 2667       322156.0     88206.0      100000.0      156193.0     202221.0
# 2668       283552.0     82716.0      100000.0      156193.0     190987.0
# 2669       306177.0     90036.0      100000.0      156193.0     190987.0
# 2670       303559.0    110532.0      109156.0      156193.0     190987.0
#
#       UNIQA_price WÁBERER_price
# 0        212210.0           NaN
# 1        174069.0           NaN
# 2        174069.0           NaN
# 3        132000.0           NaN
# 4        132000.0           NaN
# ...           ...           ...
# 2666     162103.0           NaN
# 2667     148828.0           NaN
# 2668     186970.0           NaN
# 2669     267927.0           NaN
# 2670     212210.0           NaN
#
# [2671 rows x 45 columns]

# %%
sorted(data2[data2['ALLIANZ_price'].isna()].PostalCode.tolist())
# Out:
# [2643, 4335, 5130, 5661, 5830, 6066, 7017, 7173, 8043]

# %%
sorted(data1[data1['ALLIANZ_price'].isna()].PostalCode.tolist())
# Out:
# [1056,
#  1061,
#  1222,
#  2090,
#  2164,
#  2241,
#  2532,
#  2644,
#  2660,
#  2911,
#  3042,
#  3125,
#  3240,
#  3294,
#  3377,
#  3596,
#  3776,
#  3932,
#  4354,
#  5231,
#  5536,
#  6600,
#  6635,
#  7047,
#  7165,
#  7256,
#  7500,
#  7512,
#  7526,
#  7556,
#  7772,
#  7813,
#  7826,
#  8123,
#  8751,
#  8855,
#  8878,
#  9024,
#  9111,
#  9223,
#  9234,
#  9423,
#  9664,
#  9751,
#  9773,
#  9900,
#  9922]

# %%
sorted(data3[data3['ALLIANZ_price'].isna()].PostalCode.tolist())
# Out:
# []

# %%
data3
# Out:
#      id_case DateCrawled  isRecent CarMake CarModel  CarAge  ccm  kw    kg  \
# 0        839  2024_01_34     False    FIAT    Panda       3  875  63  1165
# 1        840  2024_01_34     False    FIAT    Panda       3  875  63  1165
# 2        841  2024_01_34     False    FIAT    Panda       3  875  63  1165
# 3        842  2024_01_34     False    FIAT    Panda       3  875  63  1165
# 4        843  2024_01_34     False    FIAT    Panda       3  875  63  1165
# ..       ...         ...       ...     ...      ...     ...  ...  ..   ...
# 291     1130  2024_01_34     False    FIAT    Panda       3  875  63  1165
# 292     1131  2024_01_34     False    FIAT    Panda       3  875  63  1165
# 293     1132  2024_01_34     False    FIAT    Panda       3  875  63  1165
# 294     1133  2024_01_34     False    FIAT    Panda       3  875  63  1165
# 295     1134  2024_01_34     False    FIAT    Panda       3  875  63  1165
#
#      car_value  ...  GENERALI_price  GENERTEL_price  GROUPAMA_price  \
# 0      14664.0  ...        118507.0             NaN         76992.0
# 1      14664.0  ...        118507.0             NaN         71232.0
# 2      14664.0  ...        106033.0             NaN         79944.0
# 3      14664.0  ...         97301.0             NaN         71232.0
# 4      14664.0  ...        106033.0             NaN         71232.0
# ..         ...  ...             ...             ...             ...
# 291    14664.0  ...        118507.0             NaN         79944.0
# 292    14664.0  ...        118507.0             NaN         71232.0
# 293    14664.0  ...        118507.0             NaN         82824.0
# 294    14664.0  ...        106033.0             NaN         71232.0
# 295    14664.0  ...        143456.0             NaN         91620.0
#
#      K&AMP;H_price  KÖBE_price  MAGYAR_price  SIGNAL_price  UNION_price  \
# 0         199538.0     88206.0           NaN       97974.0      65073.0
# 1         202823.0     82716.0           NaN       97974.0      65073.0
# 2         194236.0     79056.0           NaN       97974.0      65073.0
# 3         168621.0     82716.0           NaN       97974.0      61458.0
# 4         182967.0     82716.0           NaN       97974.0      65073.0
# ..             ...         ...           ...           ...          ...
# 291       219498.0     82716.0           NaN       97974.0      61458.0
# 292       182967.0     82716.0           NaN       97974.0      65073.0
# 293       175627.0     82716.0           NaN       97974.0      61458.0
# 294       189641.0     82716.0           NaN       97974.0      61458.0
# 295       207917.0    129564.0           NaN      161658.0      72304.0
#
#      UNIQA_price WÁBERER_price
# 0       110979.0           NaN
# 1       139421.0           NaN
# 2       129801.0           NaN
# 3       110979.0           NaN
# 4       169675.0           NaN
# ..           ...           ...
# 291     129801.0           NaN
# 292      98431.0           NaN
# 293     169675.0           NaN
# 294     120878.0           NaN
# 295     169675.0           NaN
#
# [296 rows x 45 columns]
